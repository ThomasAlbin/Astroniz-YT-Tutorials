# %%
# Import NumyPy
import numpy as np

# %%
# Execute some testing code
test_var = np.random.randint(10)
print(test_var)
# Out:
# 8

# %%
# Test some plotting in this notebook
import matplotlib.pyplot as plt

# Darkmode for coolness!
plt.style.use('dark_background')

# Some random figure
plt.figure(figsize=(10, 8))
plt.plot([1.0, 10.0], [2.0, 5.0])
plt.xlabel("An X-Axis with a meaning")
plt.ylabel("The corresponding Y values")
# Out:
# Text(0, 0.5, 'The corresponding Y values')
