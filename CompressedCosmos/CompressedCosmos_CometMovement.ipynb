# %% [markdown]
# <a href="https://colab.research.google.com/github/ThomasAlbin/Astroniz-YT-Tutorials/blob/main/CompressedCosmos/CompressedCosmos_CometMovement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Comet 3I/Atlas - A cylinder?
#
# ... spoiler: no it isn't. We take a look at how a moving comet (or any other object) appears in the night sky, when we operate a telescope that is "locked" to the movement of the stars

# %%
# Install skyfield
# !pip install skyfield
# !wget -O de432s.bsp https://naif.jpl.nasa.gov/pub/naif/generic_kernels/spk/planets/de432s.bsp
# Out:
# Requirement already satisfied: skyfield in /usr/local/lib/python3.12/dist-packages (1.53)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from skyfield) (2025.10.5)
# Requirement already satisfied: jplephem>=2.13 in /usr/local/lib/python3.12/dist-packages (from skyfield) (2.23)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from skyfield) (2.0.2)
# Requirement already satisfied: sgp4>=2.13 in /usr/local/lib/python3.12/dist-packages (from skyfield) (2.25)
# --2025-10-12 10:28:47--  https://naif.jpl.nasa.gov/pub/naif/generic_kernels/spk/planets/de432s.bsp
# Resolving naif.jpl.nasa.gov (naif.jpl.nasa.gov)... 137.79.133.14
# Connecting to naif.jpl.nasa.gov (naif.jpl.nasa.gov)|137.79.133.14|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10895360 (10M) [model/vnd.valve.source.compiled-map]
# Saving to: ‘de432s.bsp’
#
# de432s.bsp          100%[===================>]  10.39M  35.5MB/s    in 0.3s
#
# 2025-10-12 10:28:48 (35.5 MB/s) - ‘de432s.bsp’ saved [10895360/10895360]

# %%
# We extract all comet data from the Minor Planet Center
from skyfield.api import load
from skyfield.data import mpc

with load.open(mpc.COMET_URL) as f:
    comets_df = mpc.load_comets_dataframe(f)

print(len(comets_df), 'comets loaded')
# Out:
# 1220 comets loaded

# %%
comets_df.head()
# Out:
#    perihelion_year  perihelion_month  perihelion_day  perihelion_distance_au  \
# 0             2026                 6         15.7267                2.587011
# 1             2027                 9          8.0457                3.419309
# 2             2000                 4          8.5312                7.076623
# 3             2025                10         30.3039                1.122834
# 4             2025                12         21.2254                3.298047
#
#    eccentricity  argument_of_perihelion_degrees  \
# 0      0.314168                        333.5036
# 1      0.243514                        244.9183
# 2      1.000796                        126.9862
# 3      0.672154                        231.3556
# 4      0.212273                        161.5333
#
#    longitude_of_ascending_node_degrees  inclination_degrees  magnitude_g  \
# 0                              40.0405               2.5990         11.5
# 1                             159.0353               5.0297         13.0
# 2                              50.3000              86.4086          2.0
# 3                             137.8408               7.5672         20.0
# 4                             285.2381               5.0301         13.5
#
#    magnitude_k              designation  reference
# 0          4.0   P/1996 R2 (Lagerkvist)  NK   1615
# 1          2.0     P/1998 VS24 (LINEAR)  MPC 75703
# 2          4.0        C/1999 J2 (Skiff)  MPC186628
# 3          2.0     P/1999 RO28 (LONEOS)  NK    731
# 4          2.0  P/1999 XN120 (Catalina)  MPC 75704

# %%
# We search for the comet with the "3I" designation
atlas_df = comets_df[comets_df['designation'].str.contains('3I')].copy()

# %%
atlas_df
# Out:
#       perihelion_year  perihelion_month  perihelion_day  \
# 1219             2025                10         29.4839
#
#       perihelion_distance_au  eccentricity  argument_of_perihelion_degrees  \
# 1219                1.356324      6.138574                        128.0125
#
#       longitude_of_ascending_node_degrees  inclination_degrees  magnitude_g  \
# 1219                             322.1574             175.1131         11.8
#
#       magnitude_k designation      reference
# 1219          4.0    3I/ATLAS  MPEC 2025-T80

# %%
from skyfield.constants import GM_SUN_Pitjeva_2005_km3_s2 as GM_SUN

atlas_row = atlas_df.iloc[0]

ts = load.timescale()
eph = load('de432s.bsp')
sun, mars = eph['sun'], eph['mars_barycenter']

comet = sun + mpc.comet_orbit(atlas_row, ts, GM_SUN)

t1 = ts.utc(2025, 10, 5, 12, 0, 0)
t2 = ts.utc(2025, 10, 5, 12, 5, 0)

comet_pos1 = mars.at(t1).observe(comet)
comet_pos2 = mars.at(t2).observe(comet)

print(f"Separation between the 2 positions: {comet_pos1.separation_from(comet_pos2)}")
# Out:
# Separation between the 2 positions: 00deg 02' 16.0"
